# %% [markdown]
# <a href="https://colab.research.google.com/github/cbowler1234/ECGR4090_Tabkhi_Hw/blob/main/Hw1Code/Hw1_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Cbowler1234/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.8.0+cu101 CPU

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images/bus.jpg
Image(filename='runs/detect/exp/bus.jpg', width=600)
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/bus.jpg', update=False, view_img=False, weights=['yolov5s.pt'])
# YOLOv5 v4.0-127-g2456b11 torch 1.8.0+cu101 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 71.5MB/s]
#
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients, 17.0 GFLOPS
# image 1/1 /content/yolov5/yolov5/yolov5/data/images/bus.jpg: model time is 0.5581140518188477
# 640x480 4 persons, 1 bus, Done. (0.560s)
# Results saved to runs/detect/exp
# Done. (0.617s)

# %%
# !python detect.py --weights yolov5m.pt --img 640 --conf 0.25 --source data/images/bus.jpg
Image(filename='runs/detect/exp2/bus.jpg', width=600)
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/bus.jpg', update=False, view_img=False, weights=['yolov5m.pt'])
# YOLOv5 v4.0-127-g2456b11 torch 1.8.0+cu101 CPU
#
# ...
# 100% 41.1M/41.1M [00:00<00:00, 54.5MB/s]
#
# Fusing layers...
# Model Summary: 308 layers, 21356877 parameters, 0 gradients, 51.3 GFLOPS
# image 1/1 /content/yolov5/yolov5/yolov5/data/images/bus.jpg: model time is 1.3379981517791748
# 640x480 4 persons, 1 bus, Done. (1.340s)
# Results saved to runs/detect/exp2
# Done. (1.396s)

# %%
# !python detect.py --weights yolov5l.pt --img 640 --conf 0.25 --source data/images/bus.jpg
Image(filename='runs/detect/exp3/bus.jpg', width=600)
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/bus.jpg', update=False, view_img=False, weights=['yolov5l.pt'])
# YOLOv5 v4.0-127-g2456b11 torch 1.8.0+cu101 CPU
#
# ...
# 100% 90.2M/90.2M [00:02<00:00, 37.5MB/s]
#
# Fusing layers...
# Model Summary: 392 layers, 47025981 parameters, 0 gradients, 115.4 GFLOPS
# image 1/1 /content/yolov5/yolov5/yolov5/data/images/bus.jpg: model time is 2.598822832107544
# 640x480 4 persons, 1 bus, 1 potted plant, Done. (2.600s)
# Results saved to runs/detect/exp3
# Done. (2.655s)

# %%
# !python detect.py --weights yolov5x.pt --img 640 --conf 0.25 --source data/images/bus.jpg
Image(filename='runs/detect/exp4/bus.jpg', width=600)
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/bus.jpg', update=False, view_img=False, weights=['yolov5x.pt'])
# YOLOv5 v4.0-127-g2456b11 torch 1.8.0+cu101 CPU
#
# ...
# 100% 168M/168M [00:05<00:00, 31.0MB/s]
#
# Fusing layers...
# Model Summary: 476 layers, 87730285 parameters, 0 gradients, 218.8 GFLOPS
# image 1/1 /content/yolov5/yolov5/yolov5/data/images/bus.jpg: model time is 4.484605550765991
# 640x480 4 persons, 1 bus, 1 potted plant, Done. (4.486s)
# Results saved to runs/detect/exp4
# Done. (4.540s)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images/intersection.jpg
Image(filename='runs/detect/exp5/intersection.jpg', width=600)
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/intersection.jpg', update=False, view_img=False, weights=['yolov5s.pt'])
# YOLOv5 v4.0-127-g2456b11 torch 1.8.0+cu101 CPU
#
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients, 17.0 GFLOPS
# image 1/1 /content/yolov5/yolov5/yolov5/data/images/intersection.jpg: model time is 0.6315121650695801
# 384x640 13 persons, 1 bicycle, 8 cars, 6 traffic lights, Done. (0.636s)
# Results saved to runs/detect/exp5
# Done. (0.707s)

# %%
# !python detect.py --weights yolov5m.pt --img 640 --conf 0.25 --source data/images/intersection.jpg
Image(filename='runs/detect/exp6/intersection.jpg', width=600)
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/intersection.jpg', update=False, view_img=False, weights=['yolov5m.pt'])
# YOLOv5 v4.0-127-g2456b11 torch 1.8.0+cu101 CPU
#
# Fusing layers...
# Model Summary: 308 layers, 21356877 parameters, 0 gradients, 51.3 GFLOPS
# image 1/1 /content/yolov5/yolov5/yolov5/data/images/intersection.jpg: model time is 1.1051661968231201
# 384x640 12 persons, 1 bicycle, 8 cars, 1 truck, 7 traffic lights, Done. (1.107s)
# Results saved to runs/detect/exp6
# Done. (1.157s)

# %%
# !python detect.py --weights yolov5l.pt --img 640 --conf 0.25 --source data/images/intersection.jpg
Image(filename='runs/detect/exp7/intersection.jpg', width=600)
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/intersection.jpg', update=False, view_img=False, weights=['yolov5l.pt'])
# YOLOv5 v4.0-127-g2456b11 torch 1.8.0+cu101 CPU
#
# Fusing layers...
# Model Summary: 392 layers, 47025981 parameters, 0 gradients, 115.4 GFLOPS
# image 1/1 /content/yolov5/yolov5/yolov5/data/images/intersection.jpg: model time is 2.124523401260376
# 384x640 15 persons, 1 bicycle, 11 cars, 1 truck, 7 traffic lights, Done. (2.127s)
# Results saved to runs/detect/exp7
# Done. (2.178s)

# %%
# !python detect.py --weights yolov5x.pt --img 640 --conf 0.25 --source data/images/intersection.jpg
Image(filename='runs/detect/exp8/intersection.jpg', width=600)
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/intersection.jpg', update=False, view_img=False, weights=['yolov5x.pt'])
# YOLOv5 v4.0-127-g2456b11 torch 1.8.0+cu101 CPU
#
# Fusing layers...
# Model Summary: 476 layers, 87730285 parameters, 0 gradients, 218.8 GFLOPS
# image 1/1 /content/yolov5/yolov5/yolov5/data/images/intersection.jpg: model time is 3.6395153999328613
# 384x640 13 persons, 1 bicycle, 7 cars, 7 traffic lights, Done. (3.641s)
# Results saved to runs/detect/exp8
# Done. (3.691s)
